# %% [markdown]
# <a href="https://colab.research.google.com/github/hjiwoong/DL/blob/main/day11_practice2_%EC%BB%A4%EC%8A%A4%ED%85%80_%ED%95%99%EC%8A%B5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# YOLO 커스텀 학습 - best.pt를 만든다
# !pip install -U ultralytics
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.4/46.4 kB 3.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 37.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.2/53.2 kB 3.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 75.4/75.4 kB 3.9 MB/s eta 0:00:00
# ...

# %%
from ultralytics import YOLO
import torch
# Out:
# Creating new Ultralytics Settings v0.0.8 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart#ultralytics-settings.

# %%
# !pip install -U wandb
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 40.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.0/60.0 kB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 72.5/72.5 kB 5.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 137.2/137.2 kB 12.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.6/204.6 kB 18.5 MB/s eta 0:00:00
# ...
#   Attempting uninstall: opentelemetry-api
#     Found existing installation: opentelemetry-api 1.42.1
#     Uninstalling opentelemetry-api-1.42.1:
#       Successfully uninstalled opentelemetry-api-1.42.1
#   Attempting uninstall: opentelemetry-semantic-conventions
#     Found existing installation: opentelemetry-semantic-conventions 0.63b1
#     Uninstalling opentelemetry-semantic-conventions-0.63b1:
#       Successfully uninstalled opentelemetry-semantic-conventions-0.63b1
#   Attempting uninstall: opentelemetry-sdk
#     Found existing installation: opentelemetry-sdk 1.42.1
# ...

# %%
import os
os.environ["WANDB_MODE"] = "online"
import wandb
print("WANDB_MODE =", os.environ.get("WANDB_MODE"))
# Out:
# WANDB_MODE = online

# %%
# 로그인 (방법 B: Colab Secrets - 권장 방법)
import os
from google.colab import userdata
os.environ["WANDB_API_KEY"] = userdata.get("WANDB_API_KEY")
import wandb
wandb.login()
# Out:
# /usr/local/lib/python3.13/dist-packages/notebook/notebookapp.py:191: SyntaxWarning: invalid escape sequence '\/'
#   | |_| | '_ \/ _` / _` |  _/ -_)
# wandb: [wandb.login()] Loaded credentials for https://api.wandb.ai from WANDB_API_KEY.
# wandb: Currently logged in as: gimm00999 (gimm00999-kwu) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# True

# %%
# 셀 1. 전이학습
model = YOLO("yolo11n.pt") # pretrained 가중치 로드 = 전이학습의 출발점

# %%
# 셀 3. 연습 학습 실행 - coco8로 파이프라인 체험
results = model.train( # 재학습 실행, 분류층
    data = "coco8.yaml",    # data.yaml 학습 주문서
    epochs = 3,
    imgsz = 320,
    batch = 4,    # 한 번에 4장씩
    project = "runs_practice",    # 결과 상위 폴더명
    name = "coco8_test",    # 이번 실행 이름
    exist_ok = True,    # 덮어쓰기 허용
    verbose = False,    # 진행 로그 최소화
)
print("학습 완료, 결과 폴더:", results.save_dir)
# Out:
# Ultralytics 8.4.146 🚀 Python-3.13.15 torch-2.11.0+cpu CPU (Intel Xeon CPU @ 2.20GHz)
# ...

# %%
# 셀 4. runs/폴더 해부 - 만들어진 것들
import os
save_dir = str(results.save_dir) # 경로 객체 → 문자열로 변환
print("[결과 폴더 내용물]")
for f in sorted(os.listdir(save_dir)): # listdir = 폴더 안 파일 목록, 정렬해서 출력
  print(" ", f)
print("weights. →", os.listdir(os.path.join(save_dir, "weights")))
# Out:
# [결과 폴더 내용물]
#   BoxF1_curve.png
#   BoxPR_curve.png
#   BoxP_curve.png
#   BoxR_curve.png
#   args.yaml
#   confusion_matrix.png
#   confusion_matrix_normalized.png
#   labels.jpg
#   results.csv
#   results.png
#   train_batch0.jpg
#   train_batch1.jpg
#   train_batch2.jpg
#   val_batch0_labels.jpg
#   val_batch0_pred.jpg
#   weights
# weights. → ['best.pt', 'last.pt']

# %%
# 셀 5. 학습률 스케줄러 - 고정 vs StrpLR vs CosineAnnealing

# %%
# 셀 6. OOM(CUDA out of memory) 대처
